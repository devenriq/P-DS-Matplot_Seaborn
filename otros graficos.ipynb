# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data= np.random.randint(1,50,100)
data
# Out:
# array([ 8, 12, 25,  9, 41, 42,  1,  2, 20,  7,  3, 22, 11, 45,  9, 10, 41,
#        20, 23, 45, 38,  2, 18,  8, 44, 48, 29,  6,  5, 16,  1, 45,  6, 37,
#         8, 36, 34, 32,  5, 14, 19,  1, 22, 40, 35, 29, 44, 31,  4, 42, 44,
#        18, 25, 19, 20,  1, 19, 28, 38,  3,  9,  4, 41, 31,  7, 31, 35, 48,
#        43, 37, 22, 26, 18, 25, 10, 43,  2, 47, 49, 32, 10, 38, 38, 38, 37,
#        46, 19, 48,  8, 14, 15, 40, 45, 17, 22, 45, 39, 46,  6, 40])

# %%
plt.hist(data,bins=15,histtype='bar')
plt.show()

# %%
plt.hist(data,bins=15,histtype='step')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
data= np.append(data,200)
plt.boxplot(data,vert=False,patch_artist=True,notch=True,showfliers=False)
plt.show()

# %% [markdown]
# ## Scatter

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
area=(30* np.random.rand(N))**2
colors = np.random.rand(N)

# %%
plt.scatter(x,y,s=area,c=colors,marker='o',alpha=0.5)
plt.show()
