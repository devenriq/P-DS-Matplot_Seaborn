# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'rx')
plt.show()

# %%
plt.plot(x,y,'bD:')
plt.show()

# %%
plt.hist(y)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
